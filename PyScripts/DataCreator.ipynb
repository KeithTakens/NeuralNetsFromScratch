# %%
import NeuralNetMain as NetMain
import importlib
importlib.reload(NetMain)

a,b,c,d,e = 2, -50, 140, -.6, 4

x,y = NetMain.generate_noisy_data(a, b, c, d, e, 1500)
polyLineX,polyLineY = NetMain.generate_polynomial(a, b, c, d, e)

NetMain.displayData(x,y,polyLineX,polyLineY)

# %%
import NeuralNetMain as NetMain
import importlib
importlib.reload(NetMain)

x,y = NetMain.generate_noisy_data(a, b, c, d, e, 1500)
NetMain.save_to_csv(x,y)
